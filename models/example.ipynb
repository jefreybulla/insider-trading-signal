# %%
import pandas as pd

# %%
df = pd.read_parquet("../ETL/data/engineered/final_data_2025Q1.parquet")
df.head(20)
# Out:
#     side  log_dollar_value      role  is_10b5_1  log_size_vs_cap  \
# 3   sell         15.441086   OFFICER          0        -9.087956
# 4   sell         14.496378  DIRECTOR          0       -10.032665
# 5    buy         13.401964   OFFICER          0        -9.559271
# 6   sell         14.673079   OFFICER          1       -10.128313
# 7   sell         11.586464  DIRECTOR          1       -13.214937
# 8   sell         15.554449   OFFICER          1        -9.246943
# 9   sell         13.269491   OFFICER          0       -10.009910
# 10  sell         15.226362   OFFICER          0        -8.053038
# 11  sell         13.603320  DIRECTOR          0        -9.676081
# 19  sell         11.336200   OFFICER          0       -11.597717
# 21   buy          9.223750  DIRECTOR          0       -11.692817
# 25   buy         12.593479   OFFICER          0       -10.037918
# 27  sell         10.391492   OFFICER          0       -13.980250
# ...
